# %% [markdown]
# # 1. Drukowanie w formacie pdf i docx
#
#     1. pandoc Untitled1.ipynb -s -o sample.docx
#     2. jupyter nbconvert --to pdfviahtml Untitled1.ipynb
# # 2. Podstawowe komendy
# Esc + a – nowa komórka przed zaznaczoną komórką
#
#
#
# Esc + dd – kasowanie komórki
#
#
#
# Esc + m – zamiana komórki na komórkę z komentarzem
#
#
#
# Esc + r – zamiana komórki, z komórki z komentarzem na komórkę z kodem
#
#
#
# Esc + z – cofnięcie skasowanej komórki
#
#
#
# Esc + strzałka w górę / w dół – przechodzenie pomiędzy komórkami

# %% [markdown]
# # 3. Kod komórki, którą chcesz zignorować przy drukowaniu
# %%capture

# %%
# %%capture
pip install matplotlib

# %%
# %%capture
pip install pandas

# %%
# %%capture
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv(r'https://analityk.edu.pl/wp-content/uploads/2020/12/data.csv')
df['date'] = pd.to_datetime(df.date, format='%d/%m/%Y')
x=df['date']
y=df['Close']

# %%
# %%capture
plt.plot(x,y)

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 110]

plt.plot(x, y)
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Wykres liniowy')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from numpy.polynomial import Polynomial

# %%
x=[1,2,10,3,4,5,6]
y=[1,4,9,50,16,25,36]
plt.scatter(x,y)
plt.xlabel('Wydatek[m3/h]')
plt.ylabel('ciśnienie [Pa]')
plt.title('wykres')
z = np.polyfit(x, y, 2)
p = p = np.poly1d(z)
print(p)
plt.plot(x, p(x))
# Out:
#         2
# -1.344 x + 15.44 x - 11.57

# %%
import pandas as pd
fake_dataset = pd.read_csv('example1.csv',header=None,sep=';')

# %%
fake_dataset.dtypes
# Out:
# 0    object
# 1    object
# 2    object
# 3    object
# 4    object
# dtype: object

# %%
fake_dataset
# Out:
#        0     1      2        3     4
# 0    1,1   2,4    3,5      4,4   5,6
# 1    1,4  2,88   3,64    10,12  5,92
# 2  1,101  2,12  9,232  11,1221  5,11
# 3   1,43  2,22   3,21      NaN  5,01
# 4   1,22  2,01   3,11    13,11  5,11
# 5   1,01  2,11   3,11      NaN  5,11

# %% [markdown]
# fake_dataset.fillna(111,inplace=True)

# %%
fake_dataset
# Out:
#        0     1      2        3     4
# 0    1,1   2,4    3,5      4,4   5,6
# 1    1,4  2,88   3,64    10,12  5,92
# 2  1,101  2,12  9,232  11,1221  5,11
# 3   1,43  2,22   3,21      NaN  5,01
# 4   1,22  2,01   3,11    13,11  5,11
# 5   1,01  2,11   3,11      NaN  5,11

# %%
a
